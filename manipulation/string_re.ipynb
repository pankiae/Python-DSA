# %% [markdown]
# **import the re module**

# %%
import re

# %% [markdown]
# ### Main functions provided by re:
#
# | Function        | What it Does                     |
# |----------------|----------------------------------|
# | `re.search()`   | Finds first match                |
# | `re.match()`    | Checks match at beginning        |
# | `re.findall()`  | Returns all matches              |
# | `re.finditer()` | Returns match objects            |
# | `re.sub()`      | Replace pattern                  |
# | `re.split()`    | Split string                     |
# | `re.compile()`  | Compile regex for reuse          |
# | `re.fullmatch()`| Matches entire string            |

# %% [markdown]
# ### 1️⃣ Core Syntax Basic Characters:
# | Pattern |   Meaning                   |
# |---------|-----------------------      |
# | `a`     |matches character 'a'       |
# | `.`     |any character except newline |
# | `\d`    |digit (0-9)                  |
# | `\D`    |non-digit                    |
# | `\w`    |word character (a-zA-Z0-9_ )  |
# | `\W`	  |non-word character           |
# | `\s`    |whitespace                   |
# | `\S`    |non-whitespace               |

# %% [markdown]
# 2️⃣ Quantifiers (Very Important in DSA):
#
# |Pattern    |   Meaning             |
# |-----------|-----------------------|
# |   `*`     |   0 or more           |
# |   `+`     |	1 or more           |
# |   `?`     |	0 or 1              |
# |   `{n}`   |exactly n times        |
# |   `{n,m}` |between n and m times  |

# %% [markdown]
# 3️⃣ Character Sets
# |   Pattern |   	Meaning         |
# |-----------|-----------------------|
# | `[abc]`   |   a or b or c         |
# | `[^abc]`  |   not a, b, or c      |
# | `[a-z]`   |   lowercase letters   |
# | `[A-Z]`   |   uppercase letters   |
# | `[0-9]`   |   digits              |

# %% [markdown]
# 4️⃣ Anchors
# |   Pattern |	Meaning         |
# |-----------|-------------------|
# |   `^`     |	start of string |
# |   `$`     |	end of string   |
# |   `\b`    |	word boundary   |

# %%
para = '''John's email is john.doe123@example.com, and his phone number is 555-123-4567. His friend Jane's contact is jane_doe456@workplace.org. They met on 2023-10-17 during a team meeting at 2:30 PM. 

The address for the meeting was: 123 Main St., Apt #4B, New York, NY 10001. The code for the event is ABC-987. 
Please reach out before 2023-10-19 if you have any questions. You can also contact us at support@company.com or https://support.company.com

Also, John’s backup email is johndoe123@backup.org. The team chat is scheduled for 2023-10-20 at 10:00 AM.'''

# %% [markdown]
# ### 1. \w or \w+ stands for the "word character".
# - It maches alphanumeric characters (letters and digits) as well as underscores (_)
# - the + in \w mean "one or more"occurrences of the preceeding element.
#     - so \w+ match *one or more* word characters (letters, digits, and underscores)
