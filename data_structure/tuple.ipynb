# %%
a_tuple = (2, True, 4.96, False)

# %%
a_tuple.append(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 a_tuple.append(1)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
a_tuple[2]
# Out:
# 4.96

# %%
a_tuple[1] = False
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 a_tuple[1] = False
#
# TypeError: 'tuple' object does not support item assignment

# %%
a_tuple.__add__(tuple([1,2]))
# Out:
# (2, True, 4.96, False, 1, 2)

# %%
print(a_tuple)
a_tuple.index(0)
# Out:
# (2, True, 4.96, False)
# 3
