# %%
data = [
    [101, "Alice", 23, ["Python", "SQL"], {"city": "NY", "score": 85}],
    [104, "Diana", 25, ["JavaScript", "HTML", "CSS"], {"city": "Chicago", "score": 88}],
    [103, "Charlie", 22, ["Python"], {"city": "NY", "score": 78}],
    [105, "Eve", 29, ["Python", "Go"], {"city": "LA", "score": 95}],
    [102, "Bob", 27, ["Java", "C++", "Python"], {"city": "LA", "score": 92}],
    [106, "Frank", 24, ["C", "C++"], {"city": "NY", "score": 80}]
]

# %%
names = []
diana_skill = []
go_user = False
for user in data:
    names.append(user[1])
    if user[1] == "Diana":
        print(user)
        diana_skill += user[3]
    if user[1]=="Frank":
        user[2] = 26
    if user[0] == 103:
        data.remove(user)
    # print(user[-1])
    if "NY" in user[-1]["city"] or user[-1]["score"]>85:
        print(user)
    if "Python" in user[3]:
        print(user)
    if not go_user and "Go" in user[3]:
        print(user)
        go_user = True
    
    
print(names)
print(diana_skill)
print(data)
# Out:
# [101, 'Alice', 23, ['Python', 'SQL'], {'city': 'NY', 'score': 85}]
# [101, 'Alice', 23, ['Python', 'SQL'], {'city': 'NY', 'score': 85}]
# [102, 'Bob', 27, ['Java', 'C++', 'Python'], {'city': 'LA', 'score': 92}]
# [102, 'Bob', 27, ['Java', 'C++', 'Python'], {'city': 'LA', 'score': 92}]
# [104, 'Diana', 25, ['JavaScript', 'HTML', 'CSS'], {'city': 'Chicago', 'score': 88}]
# [104, 'Diana', 25, ['JavaScript', 'HTML', 'CSS'], {'city': 'Chicago', 'score': 88}]
# [105, 'Eve', 29, ['Python', 'Go'], {'city': 'LA', 'score': 95}]
# [105, 'Eve', 29, ['Python', 'Go'], {'city': 'LA', 'score': 95}]
# [105, 'Eve', 29, ['Python', 'Go'], {'city': 'LA', 'score': 95}]
# [106, 'Frank', 26, ['C', 'C++'], {'city': 'NY', 'score': 80}]
# ['Alice', 'Bob', 'Diana', 'Eve', 'Frank']
# ['JavaScript', 'HTML', 'CSS']
# ...

# %%
asc_list = []

data.sort(key=lambda x: x[2])
data
# Out:
# [[103, 'Charlie', 22, ['Python'], {'city': 'NY', 'score': 78}],
#  [101, 'Alice', 23, ['Python', 'SQL'], {'city': 'NY', 'score': 85}],
#  [106, 'Frank', 24, ['C', 'C++'], {'city': 'NY', 'score': 80}],
#  [104,
#   'Diana',
#   25,
#   ['JavaScript', 'HTML', 'CSS'],
#   {'city': 'Chicago', 'score': 88}],
#  [102, 'Bob', 27, ['Java', 'C++', 'Python'], {'city': 'LA', 'score': 92}],
#  [105, 'Eve', 29, ['Python', 'Go'], {'city': 'LA', 'score': 95}]]

# %%
for i in range(len(data)):
    print(f"--- Pass {i+1} ---")
    for j in range(0, len(data)-i-1):
        if data[j][1] > data[j+1][1]:
            print(f"Swap {data[j]} and {data[j+1]}")
            data[j], data[j+1] = data[j+1], data[j]

data
# Out:
# --- Pass 1 ---
# --- Pass 2 ---
# --- Pass 3 ---
# --- Pass 4 ---
# --- Pass 5 ---
# --- Pass 6 ---
# [[101, 'Alice', 23, ['Python', 'SQL'], {'city': 'NY', 'score': 85}],
#  [102, 'Bob', 27, ['Java', 'C++', 'Python'], {'city': 'LA', 'score': 92}],
#  [103, 'Charlie', 22, ['Python'], {'city': 'NY', 'score': 78}],
#  [104,
#   'Diana',
#   25,
#   ['JavaScript', 'HTML', 'CSS'],
#   {'city': 'Chicago', 'score': 88}],
#  [105, 'Eve', 29, ['Python', 'Go'], {'city': 'LA', 'score': 95}],
#  [106, 'Frank', 24, ['C', 'C++'], {'city': 'NY', 'score': 80}]]

# %%
flat_list = []
user_skills_2 = []
flat_dict = {}
for user in data:
    skills = user[3]
    if len(skills) > 2:
        # user_skills_2.append(user[1])
        inserted = False
        for i in range(len(user_skills_2)):
            if user[1] < user_skills_2[i]:
                user_skills_2.insert(i, user[1])
                inserted = True
                break
        if not inserted:
            user_skills_2.append(user[1])

    for skill in skills:
        flat_dict[skill] = flat_dict.get(skill, 0) + 1
        inserted= False
        if i in range(len(flat_dict)):
            if skill < flat_dict[i]:
                flat_dict.
                

        if skill not in flat_list:
            iserted = False
            for i in range(len(flat_list)):
                if skill < flat_list[i]:
                    flat_list.insert(i, skill)
                    iserted = True
                    break
            
            if not iserted:
                flat_list.append(skill)
print(flat_list)
print(user_skills_2)
print(flat_dict)
# Out:
# ['C', 'C++', 'CSS', 'Go', 'HTML', 'Java', 'JavaScript', 'Python', 'SQL']
# ['Bob', 'Diana']
# {'Python': 4, 'SQL': 1, 'JavaScript': 1, 'HTML': 1, 'CSS': 1, 'Go': 1, 'Java': 1, 'C++': 2, 'C': 1}

# %%
info = {"name": "Alice"}
stats = {"score": 85, "grade": "A", "name": "Bob"}

info |= stats
info
# Out:
# {'name': 'Bob', 'score': 85, 'grade': 'A'}

# %%
a_list = [2, True, 4.96, False, 1, 2, 1]
print(a_list.index(0))
print(0 in a_list)
# Out:
# 3
# True

# %%
count = 0
count = sum([i for i in a_list if not isinstance(i, bool) and i == 1])
count
# Out:
# 2
