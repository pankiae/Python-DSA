# %%
a_string = 'keyword value'

# %%
a_string[2]
# Out:
# 'y'

# %%
a_string.center(10)
# Out:
# 'keyword value'

# %%
a_string.count("w")
# Out:
# 1

# %%
a_string.ljust(2)
# Out:
# 'keyword value'

# %%
a_string.rjust(2)
# Out:
# 'keyword value'

# %%
a_string
# Out:
# 'keyword value'

# %%
a_string.find("w")
# Out:
# 3

# %%
split_string = a_string.split("f")
print(split_string)
# Out:
# ['keyword value']

# %%
list(a_string)
# Out:
# ['k', 'e', 'y', 'w', 'o', 'r', 'd', ' ', 'v', 'a', 'l', 'u', 'e']
