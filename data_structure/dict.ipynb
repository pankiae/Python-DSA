# %%
capitals = {"Iowa": "Des Moines", "Wisconsin": "Madison"}

# %%
capitals["Utah"] = "Salt Lake City"
print(capitals)
# Out:
# {'Iowa': 'Des Moines', 'Wisconsin': 'Madison', 'California': 'Sacramento', 'Utah': 'Salt Lake City'}

# %%
capitals["California"] = "Sacramento"
print(capitals)
# Out:
# {'Iowa': 'Des Moines', 'Wisconsin': 'Madison', 'California': 'Sacramento'}

# %%
print(capitals)
# Out:
# {'Iowa': 'Des Moines', 'Wisconsin': 'Madison', 'California': 'Sacramento', 'Utah': 'Salt Lake City'}

# %%
len(capitals)
# Out:
# 4

# %%
list(capitals)
# Out:
# ['Iowa', 'Wisconsin', 'California', 'Utah']

# %%
for i in capitals.items():
    print(i)
# Out:
# ('Iowa', 'Des Moines')
# ('Wisconsin', 'Madison')
# ('California', 'Sacramento')
# ('Utah', 'Salt Lake City')
