# %%
class User:
    pass

u = User()

print("type(u):", type(u))
print("type(User):", type(User))
print("User.__bases__:", User.__bases__)
print("type(object):", type(object))
print("object.__bases__:", object.__bases__)

print("Is User instance of type?", isinstance(User, type))
print("Is u instance of User?", isinstance(u, User))
print("Is User subclass of object?", issubclass(User, object))

# %%
class MyMeta(type):

    def __new__(cls, name, bases, attrs):
        print(f"Creating class {name}")
        return super().__new__(cls, name, bases, attrs)


class Car(metaclass=MyMeta):
    pass
# Out:
# Creating class Car
